# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b928a82e-7a2e-407d-acbc-10b64f233ac4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b928a82e-7a2e-407d-acbc-10b64f233ac4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving survey.xls to survey.xls
# {'survey.xls': b'\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00\xfe\xff\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00*\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\xfe\xff\xff\xff\x00\x00\x00\x00\xfe\xff\xff\xff\x00\x00\x00\x00)\t\x08\x08\x00\x00\x05\x05\x00\xc9K\xcd\x07\xe1\x00\x00\x00\xc1\x00\x02\x00\x00\x00\xbf\x00\x00\x00\xc0\x00\x00\x00\xe2\x00\x00\x00\\\x00p\x00\x06learnp                                                                                                         B\x00\x02\x00\xe4\x04\x9c\x00\x02\x00\x11\x00\x19\x00\x02\x00\x00\x00\x12\x00\x02\x00\x00\x00\x13\x00\x02\x00\x00\x00=\x00\x12\x00\x00\x00\x00\x00@V\xd2-8\x00\x00\x00\x00\x00\x01\x00X\x02@\x00\x02\x00\x00\x00\x8d\x00\x02\x00\x00\x00"\x00\x02\x00\x00\x00\x0e\x00\x02\x00\x01\x00\xb7\x01\x02\x00\x00\x00\xda\x00\x02\x00\x00\x001\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x1c\x00h\x01\x00\x006\x00\x90\x01\x00\x00\x00\x02\x00\x02\rCalibri Light1\x00\x16\x00,\x01\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\x04\x01\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x11\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x14\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00<\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00>\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x01\x00?\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x01\x004\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x004\x00\x90\x01\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x01\x00\t\x00\xbc\x02\x00\x00\x00\x02\x00\x02\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\n\x00 ...

# %%
df = pd.read_excel("survey.xls")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Sex,df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
pd.crosstab(df.Sex,df.Handedness, margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
pd.crosstab(df.Sex, [df.Handedness,df.Nationality], margins=True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %%
pd.crosstab([df.Nationality, df.Sex], [df.Handedness], margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
pd.crosstab(df.Sex, df.Handedness, normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %%
import numpy as np

# %%
pd.crosstab(df.Sex, df.Handedness, values=df.Age, aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0
