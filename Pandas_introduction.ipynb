# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0379a95f-d7b3-4865-b9b2-05ff7b194df8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0379a95f-d7b3-4865-b9b2-05ff7b194df8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nyc_weather.csv to nyc_weather.csv
# {'nyc_weather.csv': b'EST,Temperature,DewPoint,Humidity,Sea Level PressureIn,VisibilityMiles,WindSpeedMPH,PrecipitationIn,CloudCover,Events,WindDirDegrees,\r\n01/01/2016,38,23,52,30.03,10,8,0,5,,281,\r\n01/02/2016,36,18,46,30.02,10,7,0,3,,275,\r\n01/03/2016,40,21,47,29.86,10,8,0,1,,277,\r\n01/04/2016,25,9,44,30.05,10,9,0,3,,345,\r\n01/05/2016,20,-3,41,30.57,10,5,0,0,,333,\r\n01/06/2016,33,4,35,30.5,10,4,0,0,,259,\r\n01/07/2016,39,11,33,30.28,10,2,0,3,,293,\r\n01/08/2016,39,29,64,30.2,10,4,0,8,,79,\r\n01/09/2016,44,38,77,30.16,9,8,T,8,Rain,76,\r\n01/10/2016,50,46,71,29.59,4,,1.8,7,Rain,109,\r\n01/11/2016,33,8,37,29.92,10,,0,1,,289,\r\n01/12/2016,35,15,53,29.85,10,6,T,4,,235,\r\n1/13/2016,26,4,42,29.94,10,10,0,0,,284,\r\n1/14/2016,30,12,47,29.95,10,5,T,7,,266,\r\n1/15/2016,43,31,62,29.82,9,5,T,2,,101,\r\n1/16/2016,47,37,70,29.52,8,7,0.24,7,Rain,340,\r\n1/17/2016,36,23,66,29.78,8,6,0.05,6,Fog-Snow,345,\r\n1/18/2016,25,6,53,29.83,9,12,T,2,Snow,293,\r\n1/19/2016,22,3,42,30.03,10,11,0,1,,293,\r\n1/20/2016,32,15,49,30.13,10,6,0,2,,302,\r\n1/21/2016,31,11,45,30.15,10,6,0,1,,312,\r\n1/22/2016,26,6,41,30.21,9,,0.01,3,Snow,34,\r\n1/23/2016,26,21,78,29.77,1,16,2.31,8,Fog-Snow,42,\r\n1/24/2016,28,11,53,29.92,8,6,T,3,Snow,327,\r\n1/25/2016,34,18,54,30.25,10,3,0,2,,286,\r\n1/26/2016,43,29,56,30.03,10,7,0,2,,244,\r\n1/27/2016,41,22,45,30.03,10,7,T,3,Rain,311,\r\n1/28/2016,37,20,51,29.9,10,5,0,1,,234,\r\n1/29/2016,36,21,50,29.58,10,8,0,4,,298,\r\n1/30/2016,34,16,46,30.01,10,7,0,0,,257,\r\n1/31/2016,46,28,52,29.9,10,5,0,0,,241,\r\n'}

# %%
df = pd.read_csv('nyc_weather.csv')
df
# Out:
#            EST  Temperature  DewPoint  ...    Events  WindDirDegrees  Unnamed: 11
# 0   01/01/2016           38        23  ...       NaN             281          NaN
# 1   01/02/2016           36        18  ...       NaN             275          NaN
# 2   01/03/2016           40        21  ...       NaN             277          NaN
# 3   01/04/2016           25         9  ...       NaN             345          NaN
# 4   01/05/2016           20        -3  ...       NaN             333          NaN
# 5   01/06/2016           33         4  ...       NaN             259          NaN
# 6   01/07/2016           39        11  ...       NaN             293          NaN
# 7   01/08/2016           39        29  ...       NaN              79          NaN
# 8   01/09/2016           44        38  ...      Rain              76          NaN
# 9   01/10/2016           50        46  ...      Rain             109          NaN
# 10  01/11/2016           33         8  ...       NaN             289          NaN
# 11  01/12/2016           35        15  ...       NaN             235          NaN
# 12   1/13/2016           26         4  ...       NaN             284          NaN
# 13   1/14/2016           30        12  ...       NaN             266          NaN
# 14   1/15/2016           43        31  ...       NaN             101          NaN
# 15   1/16/2016           47        37  ...      Rain             340          NaN
# 16   1/17/2016           36        23  ...  Fog-Snow             345          NaN
# 17   1/18/2016           25         6  ...      Snow             293          NaN
# 18   1/19/2016           22         3  ...       NaN             293          NaN
# 19   1/20/2016           32        15  ...       NaN             302          NaN
# 20   1/21/2016           31        11  ...       NaN             312          NaN
# 21   1/22/2016           26         6  ...      Snow              34          NaN
# 22   1/23/2016           26        21  ...  Fog-Snow              42          NaN
# 23   1/24/2016           28        11  ...      Snow             327          NaN
# 24   1/25/2016           34        18  ...       NaN             286          NaN
# 25   1/26/2016           43        29  ...       NaN             244          NaN
# 26   1/27/2016           41        22  ...      Rain             311          NaN
# 27   1/28/2016           37        20  ...       NaN             234          NaN
# 28   1/29/2016           36        21  ...       NaN             298          NaN
# 29   1/30/2016           34        16  ...       NaN             257          NaN
# 30   1/31/2016           46        28  ...       NaN             241          NaN
#
# [31 rows x 12 columns]

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8     01/09/2016
# 9     01/10/2016
# 15     1/16/2016
# 26     1/27/2016
# Name: EST, dtype: object

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903
